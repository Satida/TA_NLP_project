# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Wed Dec 11 03:18:26 2019

@author: satida
"""
from Utils.Utils import SortFa

class Replacement:
    
    def execute(self,_dict:list):
        
        final_res=[]
        for word in _dict:
            temp=list(self.DollerControl(word))
            final_res+=temp
                
        return SortFa(final_res)
    
    
    
    def DollerControl(self , word):
        main_word=word[:]
        res_words=[]
        for i,w in enumerate(main_word):
            word=main_word[i:]+"$"+ main_word[:i]
            res_words.append(word.replace(",",""))
        return res_words
